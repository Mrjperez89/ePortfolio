# %%
# SNHU, Justin D. Perez
# Professor Hari Paruchuri
# June 9, 2024

#Updated & Modifed Code:
#Unmodifed Code: Kept the same because my main focus change was with the dashboard.

# Import the AnimalShelter class from the CRUD module
from animal_shelter import AnimalShelter  # Replace 'animal_shelter' with the actual name of your module

# Connection Variables
# MongoDB connection credentials
USERNAME = 'aacuser'
PASSWORD = 'Hotdog24'
HOST = 'nv-desktop-services.apporto.com'
PORT = 31836
# Database and collection names
DATABASE_NAME = 'AAC'
COLLECTION_NAME = 'animals'

# Instantiate the AnimalShelter class with the MongoDB connection details
animal_shelter = AnimalShelter(USERNAME, PASSWORD, HOST, PORT, DATABASE_NAME, COLLECTION_NAME)

# Example data to insert into the database
data_to_insert = {
    'name': 'Frank',  # Use the name 'Frank'
    'animal_type': 'Dog',
    'age': 2,  # Change the age to 2 years as per the database entry
    'breed': 'Chihuahua Shorthair Mix'  # Use the breed 'Chihuahua Shorthair Mix' as per the database entry
}

# Test the create method to insert the example data into the database
insert_result = animal_shelter.create(data_to_insert)
print(f"Insert Result: {insert_result}")

# Query criteria to find a dog named 'Frank' in the database
query_criteria = {'name': 'Frank'}

# Test the read method to find a dog with the name 'Frank'
read_result = animal_shelter.read(query_criteria)
print(f"Read Result: {read_result}")

# Test the update method to update the age of 'Frank' to 3 years
update_data = {'age': 3}
update_result = animal_shelter.update(query_criteria, update_data)
print(f"Update Result: {update_result}")

# Verify the update by reading the updated document
read_result_after_update = animal_shelter.read(query_criteria)
print(f"Read Result After Update: {read_result_after_update}")

# Test the delete method to remove 'Frank' from the database
delete_result = animal_shelter.delete(query_criteria)
print(f"Delete Result: {delete_result}")

# Verify the deletion by attempting to read the deleted document
read_result_after_delete = animal_shelter.read(query_criteria)
print(f"Read Result After Delete: {read_result_after_delete}")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[1], line 32
#      24 data_to_insert = {
#      25     'name': 'Frank',  # Use the name 'Frank'
#      26     'animal_type': 'Dog',
#      27     'age': 2,  # Change the age to 2 years as per the database entry
#      28     'breed': 'Chihuahua Shorthair Mix'  # Use the breed 'Chihuahua Shorthair Mix' as per the database entry
#      29 }
#      31 # Test the create method to insert the example data into the database
# ---> 32 insert_result = animal_shelter.create(data_to_insert)
#      33 print(f"Insert Result: {insert_result}")
#      35 # Query criteria to find a dog named 'Frank' in the database
#
# File ~\CS 499 Project\animal_shelter.py:23, in AnimalShelter.create(self, data)
#      19 def create(self, data):
#      20     # Insert a document into the specified MongoDB database and collection.
# ...
